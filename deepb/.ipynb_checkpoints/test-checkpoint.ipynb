# %%
from main import master_function

# %%
gene_file_path = 'input/input_genes.txt'
phenotype_file_path = 'input/input_phenotype.txt'

# %%
final_res, df_genes, phenos = master_function(phenotype_file_path,gene_file_path)

# %%
final_res
# Out:
#        gene      variant                    id  final_score  \
# 0       CBS     c.833T>C   chr21:g.44483184A>G     7.783641
# 1    EXOSC8     c.815G>C   chr13:g.37583420G>C     7.708397
# 2     MEGF8    c.8180G>A   chr19:g.42880569G>A     5.527655
# 3    CLCNKA     c.910C>T    chr1:g.16354556C>T     5.132180
# 4     PGAP3      c.67G>A   chr17:g.37844201C>T     5.083242
# 5     CCBE1     c.344C>T   chr18:g.57136761G>A     4.154201
# 6      GNAS  c.*293+1G>A   chr20:g.57478847G>A     4.062075
# 7      FLNA    c.3611C>T   chrX:g.153588552G>A     3.922368
# 8      RTTN    c.4275G>C   chr18:g.67755252C>G     3.420056
# 9     WNT7A   c.299-4G>A    chr3:g.13896304C>T     3.376938
# 10   CAMKMT     c.493G>T    chr2:g.44934538G>T     3.056788
# 11    ACACA    c.3496A>G   chr17:g.35564641T>C     3.031660
# 12     WWOX     c.990C>G   chr16:g.78466583C>G     2.939219
# 13    NPHP4    c.2246T>C     chr1:g.5950986A>G     2.728738
# 14      WAS     c.995T>C    chrX:g.48547112T>C     2.490538
# 15    ARMC5    c.2303A>G   chr16:g.31477609A>G     2.273745
# 16  CACNA1D    c.3881C>T    chr3:g.53796059C>T     2.068106
# 17    FANCL     c.979C>G    chr2:g.58388713G>C     2.031038
# 18   COL4A1    c.1402C>T  chr13:g.110845240G>A     1.880097
# 19    UBAC2     c.332T>C   chr13:g.99896821T>C     1.810618
# 20     H6PD    c.1342G>A     chr1:g.9323894G>A     1.647918
# 21    GP1BA    c.1763T>C    chr17:g.4837662T>C     1.559581
# 22      MPO    c.1348G>A   chr17:g.56352920C>T     1.373265
# 23    OSTM1     c.238C>A   chr6:g.108395618G>T     1.213008
# 24      GSN    c.1663G>A   chr9:g.124088928G>A     1.213008
# 25     TMC8     c.913C>T   chr17:g.76130571C>T     1.030827
# 26     LIPE    c.1210C>T   chr19:g.42914668G>A     0.735622
# 27  SHROOM4    c.3364A>C    chrX:g.50350778T>G     0.649641
# 28     TP53     c.558T>A    chr17:g.7578372A>T     0.554518
# 29    SALL2    c.2718G>T   chr14:g.21991144C>A     0.405465
# 30    PDSS1    c.1055G>A   chr10:g.27031454G>A     0.376019
# 31    MYO7A     c.687C>T   chr11:g.76868002C>T     0.000000
# 32    FANCM    c.2716A>T   chr14:g.45644673A>T     0.000000
# 33    NRXN1    c.2242C>A    chr2:g.50765412G>T    -0.101366
# 34     PLEC    c.5438G>A   chr8:g.144999070C>T    -0.287823
# 35    ABCA4    c.5693G>A    chr1:g.94476377C>T    -0.410557
# 36  DYNC1H1   c.13808G>T  chr14:g.102516531G>T    -0.627741
# 37     MYH2    c.3884G>A   chr17:g.10430361C>T    -0.687218
# 38     NOD2    c.2377G>A   chr16:g.50746199G>A    -1.145363
# 39     NOD2    c.1292C>T   chr16:g.50745114C>T    -1.145363
# 40     MMP1   c.105+2T>C  chr11:g.102668717A>G    -1.374436
# 41     GJC2    c.1193C>T   chr1:g.228346652C>T    -1.917842
# 42      HFE     c.845G>A    chr6:g.26093141G>A    -2.079442
# 43   ATP2A2  c.464-70C>A  chr12:g.110760727C>A    -2.772589
# 44    CDH23    c.3293A>G   chr10:g.73472494A>G    -3.003638
#
#     pathogenicity_score           pathogenicity             hit_criteria  \
# 0              4.000000       Likely pathogenic          PS1|PM5|PP3|PP5
# 1              5.125000              Pathogenic  PS1|PM5|PM1|PP3|PP2|PP5
# 2              2.250000  Uncertain significance              PM1|PM2|PP3
# 3              3.500000  Uncertain significance                 PVS1|PP3
# 4              2.333333  Uncertain significance              PM1|PM2|PP3
# 5              1.875000  Uncertain significance              PM1|PP3|PP2
# 6              1.500000  Uncertain significance                  PM2|PP3
# 7              1.375000  Uncertain significance                  PM2|PP3
# 8              2.125000  Uncertain significance              PM1|PM2|PP3
# 9              1.500000  Uncertain significance                  PM2|PP3
# 10             1.300000  Uncertain significance                  PM1|PP3
# 11             2.333333  Uncertain significance              PM1|PM2|PP3
# 12             1.250000  Uncertain significance                  PM1|PP3
# 13             1.500000  Uncertain significance                  PM1|PP3
# 14             1.250000  Uncertain significance                  PM1|PP3
# 15             1.750000  Uncertain significance          PM1|PM2|PP3|BP1
# 16             1.375000  Uncertain significance                  PM1|PP3
# 17             0.750000  Uncertain significance              PM1|PP3|BP1
# 18             1.250000  Uncertain significance                  PM1|PP3
# 19             1.125000  Uncertain significance                  PM1|PP3
# 20             1.500000  Uncertain significance                  PM1|PP3
# 21             2.250000  Uncertain significance              PM1|PM2|PP3
# 22             1.250000  Uncertain significance                  PM1|PP3
# 23             1.750000  Uncertain significance          PM1|PM2|PP3|BP1
# 24             1.750000  Uncertain significance              PM1|PP3|PP2
# 25             1.125000  Uncertain significance                  PM1|PP3
# 26             0.750000  Uncertain significance              PM1|PP3|BP1
# 27             0.500000  Uncertain significance                  PM1|BP4
# 28             0.400000  Uncertain significance                      PP3
# 29             1.000000           Likely benign          PM1|PM2|BP1|BP4
# 30             0.250000  Uncertain significance                      PP3
# 31             0.000000           Likely benign              PM2|BP7|BP6
# 32             0.000000           Likely benign              PM1|BP1|BP4
# 33            -0.250000  Uncertain significance                  PP3|BP1
# 34            -0.125000           Likely benign      PM1|PM2|BS2|PP3|BP1
# 35            -0.250000  Uncertain significance          PM1|BS2|PP3|PP5
# 36            -0.375000  Uncertain significance                  PP3|BP6
# 37            -0.750000  Uncertain significance              PM1|BS2|PP3
# 38            -1.250000           Likely benign          PM1|BS2|PP3|BP6
# 39            -1.250000           Likely benign          PM1|BS2|PP3|BP6
# 40            -1.500000  Uncertain significance                  BS2|PP3
# 41            -1.125000           Likely benign          PM1|BS2|PP3|BP6
# 42            -1.500000  Uncertain significance                  BS1|PP3
# 43            -2.000000  Uncertain significance                      BS2
# 44            -2.166667           Likely benign              BS2|PP3|BP6
#
#     hpo_hit_score
# 0        6.000000
# 1        3.500000
# 2       10.666667
# 3        3.333333
# 4        7.833333
# 5        8.166667
# 6       14.000000
# 7       16.333333
# 8        4.000000
# 9        8.500000
# 10       9.500000
# 11       2.666667
# 12       9.500000
# 13       5.166667
# 14       6.333333
# 15       2.666667
# 16       3.500000
# 17      14.000000
# 18       3.500000
# 19       4.000000
# 20       2.000000
# 21       1.000000
# 22       2.000000
# 23       1.000000
# 24       1.000000
# 25       1.500000
# 26       1.666667
# 27       2.666667
# 28       3.000000
# 29       0.500000
# 30       3.500000
# 31       2.500000
# 32      13.000000
# 33       0.500000
# 34       9.000000
# 35       4.166667
# 36       4.333333
# 37       1.500000
# 38       1.500000
# 39       1.500000
# 40       1.500000
# 41       4.500000
# 42       3.000000
# 43       3.000000
# 44       3.000000

# %%
with open('result/pubmed_query_results.csv', 'rb') as f:
    x_raw, y_test, genes, variants, titles, texts, impactfactors, years, journals = [], [], [], [], [], [], [], [], []
    f.readline()
    for line in f.readlines():
        text = line.rstrip()
        parts = text.split('\t')
        title, text, gene, variant, protein, impactfactor, year, journal = parts[3], parts[7], parts[0], parts[1], parts[2], parts[6], parts[5], parts[4]
#         x_raw.append(dataloader.extractSentencesFromText(title, text, gene, variant, protein))
#         y_test.append(1)
#         genes.append(gene)
#         variants.append(variant)
#         titles.append(title)
#         texts.append(text)
#         impactfactors.append(impactfactor)
#         years.append(year)
#         journals.append(journal)

# %%
title
# Out:
# 'Hereditary hemochromatosis masquerading as rheumatoid arthritis.'

# %%
text
# Out:
# "Early erroneous diagnosis of rheumatic disease is common in subjects with arthropathy due to hereditary hemochromatosis. A 71-year-old male with chronic obstructive pulmonary disease and monoclonal gammopathy underwent hip replacement and was referred to our Department because of altered liver function tests. Test results were negative for hepatitis B surface antigen and hepatitis C virus, and positive for rheumatoid factor. A diagnosis of rheumatoid arthritis had been made on the basis of compatible joint involvement and laboratory data and steroid treatment prescribed. Since his serum ferritin was 3249 ng/mL, genetic testing for hereditary hemochromatosis was carried out and revealed homozygosity for Cys282Tyr mutation in the HFE gene. Liver biopsy disclosed cirrhosis compatible with hemochromatosis. Following a review of the patients' radiographs, the diagnosis of hemochromatosis arthropathy was made. Phlebotomies and family screening for hereditary hemochromatosis were done. The most logical explanation for the positive rheumatoid factor result in this subject are his age and the presence of two chronic diseases involving long-standing antigenic stimulation and monoclonal gammopathy of uncertain significance. It is important to distinguish rheumatoid arthritis from hemochromatosis arthropathy for several reasons: patients with hereditary hemochromatosis do not require corticosteroid treatment; in case of erroneous diagnosis of rheumatoid arthritis, phlebotomy is not started early, and familial genetic counseling is not considered. In male subjects with positive rheumatoid factor and joint and liver disease, hereditary hemochromatosis should be considered. More liberal use of genetic testing is justified in such cases."

# %%
gene
# Out:
# 'HFE'

# %%
variant
# Out:
# 'c.845G>A'

# %%
protein
# Out:
# 'p.Cys282Tyr'

# %%
impactfactor
# Out:
# '0.5'

# %%
year
# Out:
# ''

# %%
journal
# Out:
# 'Annali italiani di medicina interna : organo ufficiale della Societa italiana di medicina interna'

# %%
import os.path
BASE = os.path.dirname(os.path.abspath(__file__))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-fbe53c644428> in <module>()
#       1 import os.path
# ----> 2 BASE = os.path.dirname(os.path.abspath(__file__))
#
# NameError: name '__file__' is not defined

# %%
eval_path = 'eval.py'
pubmed_query_results_path = 'result/pubmed_query_results.csv'
prediction_filters345_path = 'result/prediction_filters345.csv'
prediction_filters246_path =  'result/prediction_filters246.csv'
model345_3000_path = 'data/model/sentclass_filters345/model-3000'
model246_3000_path = 'data/model/sentclass_filters246/model-3000'
vocab345_path = 'data/model/sentclass_filters345/vocab'
vocab246_path = 'data/model/sentclass_filters246/vocab'

os.system('python %s --eval_data_file %s --outfile %s --checkpoint_file %s --vocab_file %s' % (eval_path, pubmed_query_results_path,prediction_filters345_path,model345_3000_path,vocab345_path))
# Out:
# 256

# %%
import pandas as pd

# %%
df = pd.read_csv('pubmed_data_variantnotnull.txt', sep='\t', header=-1)

# %%
(gene varchar(20), protein_variant varchar(30), pmid varchar(15), title tinytext, journal tinytext, year char(4), month char(3), impact_factor float(4,2), abstract text, variant_id varchar(30), protein_domain varchar(500));

# %%
df.columns = [
    'gene',
    'protein_variant',
    'pmid',
    'title',
    'journal',
    'year',
    'month',
    'impact_factor',
    'abstract',
    'variant_id',
    'protein_domain'
]

# %%
df
# Out:
#             gene protein_variant      pmid  \
# 0              T     p.Leu153Phe  22040064
# 1        SLC44A2     p.Arg154Gln  22040064
# 2       APOBEC-1     p.Glu181Gln  22326345
# 3        CYP21A2     p.Val281Leu  22886582
# 4           CD59       c.146delA  24383981
# 5              T       c.1096C>T  25814141
# 6            C4A       p.Cys4Ala  26493816
# 7            C4B       p.Cys4Asx  26493816
# 8            C4A       p.Cys4Asx  26493816
# 9            C4B       p.Cys4Ala  26493816
# 10             T       p.Asp0Asx  26526993
# 11          BRAF     p.Val600Glu  26565903
# 12             T       p.Thr1Asp  26578518
# 13          JAK2     p.Val617Phe  26650379
# 14         MTHFR     p.Cys677Thr  26681493
# 15          AIDA       p.Thr1Asp  26692253
# 16         IL-10       p.Ser9Ala  26708990
# 17          TLR4       p.Cys3His  26771084
# 18         EPHA2    p.Asp1235Lys  26910424
# 19         EPHA2     p.Arg957Asp  26910424
# 20         EPHA2     p.Lys956Asp  26910424
# 21         EPHA2    p.Asp1223Arg  26910424
# 22          RYR1    p.Glu4242Gly  26910427
# 23      APOBEC3F     p.Ile231Val  26942578
# 24      APOBEC3F       p.Ala3Gly  26942578
# 25      APOBEC3F       p.Ala3Phe  26942578
# 26           SDS     p.Glu294Arg  26956237
# 27           SDS     p.His467Ala  26956237
# 28          SIK2      p.Ser89Ala  26983400
# 29         AGXT2     p.Val498Leu  26984639
# ...          ...             ...       ...
# 357012      ESR1      p.Thr47Asp  21182832
# 357013      OGG1     p.Lys751Gln  21183201
# 357014      CAV2    p.Arg1349Gln  21183743
# 357015      PKD2     p.Asp530Asn  21185261
# 357016      PKD2     p.Asp523Glu  21185261
# 357017      PKD2     p.Asp523Asn  21185261
# 357018      PKD2    p.Asp2049Asn  21185261
# 357019      PKD2    p.Glu2072Gln  21185261
# 357020      PKD2     p.Asp525Asn  21185261
# 357021     KLF15       p.Thr2Asp  21187013
# 357022       CA2     p.Glu412Gly  21187073
# 357023       CA2     p.Thr441Ala  21187073
# 357024       CA2     p.Cys561Ala  21187073
# 357025       CA2     p.Arg560Val  21187073
# 357026     XRCC1     p.Leu751Gln  21188533
# 357027     XRCC1     p.Asp312Asn  21188533
# 357028       NF1     p.Val600Glu  21190184
# 357029       CA3      p.Cys57Asx  21190219
# 357030     NTRK1     p.Val600Glu  21190444
# 357031   SLITRK6       p.Asp2Arg  21192083
# 357032     ITGA2     p.Gly873Ala  21193198
# 357033     IGF-1       p.Ser6Lys  21193562
# 357034       CA3       p.Tyr2Arg  21195134
# 357035      OGG1     p.Ile223Val  21195604
# 357036        F7     p.Val158Met  21195697
# 357037        C3     p.Val158Met  21195697
# 357038      CD27       p.Asx8Arg  21195803
# 357039      TMC8     p.Asn306Ile  21196704
# 357040      TMC8       p.Asn306l  21196704
# 357041     LOXL1     p.Tyr559Asp  21197115
#
#                                                     title  \
# 0       Frequencies of SLC44A2 alleles encoding human ...
# 1       Frequencies of SLC44A2 alleles encoding human ...
# 2       Hypermutation of ApoB mRNA by rat APOBEC-1 ove...
# 3       Complement component 4 copy number variation a...
# 4       A new blood group antigen is defined by anti-C...
# 5       Caspase-8 Deficiency Presenting as Late-Onset ...
# 6       Gene copy-number variations (CNVs) of compleme...
# 7       Gene copy-number variations (CNVs) of compleme...
# 8       Gene copy-number variations (CNVs) of compleme...
# 9       Gene copy-number variations (CNVs) of compleme...
# 10      Human Obesity Associated with an Intronic SNP ...
# 11      AKT1 Activation Promotes Development of Melano...
# 12      Antibody Response to Serpin B13 Induces Adapti...
# 13      Polycythemia is associated with bone loss and ...
# 14      Association between MTHFR C677T polymorphism a...
# 15      Interleukin-1 antagonism moderates the inflamm...
# 16      Syk negatively regulates TLR4-mediated IFNβ an...
# 17      Cell-Permeable Peptide Blocks TLR4 Signaling a...
# 18      Dissociation of a Dynamic Protein Complex Stud...
# 19      Dissociation of a Dynamic Protein Complex Stud...
# 20      Dissociation of a Dynamic Protein Complex Stud...
# 21      Dissociation of a Dynamic Protein Complex Stud...
# 22      Distinct Components of Retrograde Ca(V)1.1-RyR...
# 23      Role of APOBEC3F Gene Variation in HIV-1 Disea...
# 24      Role of APOBEC3F Gene Variation in HIV-1 Disea...
# 25      Role of APOBEC3F Gene Variation in HIV-1 Disea...
# 26      Expression, characterization and mutagenesis o...
# 27      Expression, characterization and mutagenesis o...
# 28      SIK2 regulates fasting-induced PPARα activity ...
# 29      Associations of functional alanine-glyoxylate ...
# ...                                                   ...
# 357012  Expression of estrogen and progesterone recept...
# 357013  DNA repair gene polymorphisms at XRCC1, XRCC3,...
# 357014  Recurrent stroke due to a novel voltage sensor...
# 357015  The single pore residue Asp523 in PKD2L1 deter...
# 357016  The single pore residue Asp523 in PKD2L1 deter...
# 357017  The single pore residue Asp523 in PKD2L1 deter...
# 357018  The single pore residue Asp523 in PKD2L1 deter...
# 357019  The single pore residue Asp523 in PKD2L1 deter...
# 357020  The single pore residue Asp523 in PKD2L1 deter...
# 357021  Bio-informatics analysis of a gene co-expressi...
# 357022  Characterization of sarcoplasmic reticulum Ca2...
# 357023  Characterization of sarcoplasmic reticulum Ca2...
# 357024  Characterization of sarcoplasmic reticulum Ca2...
# 357025  Characterization of sarcoplasmic reticulum Ca2...
# 357026  An association between DNA repair gene polymor...
# 357027  An association between DNA repair gene polymor...
# 357028  Functional characterization of a BRAF insertio...
# 357029  Chronic corticosterone exposure alters postsyn...
# 357030  Prevalence, clinicopathologic features, and so...
# 357031  Region-specific gene expression in early postn...
# 357032  Predictive role of polymorphisms in interleuki...
# 357033  Chronic heart failure reduces Akt phosphorylat...
# 357034  Vulnerability to nicotine abstinence-related s...
# 357035  First evidence for digenic inheritance in here...
# 357036  The effects of catechol-O-methyl-transferase p...
# 357037  The effects of catechol-O-methyl-transferase p...
# 357038  Long term recall of memory CD8 T cells in mice...
# 357039  Homozygosity for the c.917A→T (p.N306l) polymo...
# 357040  Homozygosity for the c.917A→T (p.N306l) polymo...
# 357041  Analysis of LOXL1 polymorphisms in a Saudi Ara...
#
#                                                   journal    year month  \
# 0                                             Transfusion  2012.0   May
# 1                                             Transfusion  2012.0   May
# 2                            Journal of molecular biology  2012.0   Apr
# 3                                          Human genetics  2012.0   Dec
# 4                                             Transfusion  2014.0   Jul
# 5                          Journal of clinical immunology  2015.0   May
# 6                        Annals of the rheumatic diseases  2016.0   Sep
# 7                        Annals of the rheumatic diseases  2016.0   Sep
# 8                        Annals of the rheumatic diseases  2016.0   Sep
# 9                        Annals of the rheumatic diseases  2016.0   Sep
# 10                                           Cell reports  2015.0   Nov
# 11                                           Cell reports  2015.0   Nov
# 12                    The Journal of biological chemistry  2016.0   Jan
# 13      Osteoporosis international : a journal establi...  2016.0   Apr
# 14                          Psychology, health & medicine  2016.0    09
# 15                         European journal of immunology  2016.0   Apr
# 16                          Biochimica et biophysica acta  2016.0   Mar
# 17                                   Cell transplantation  2016.0   NaN
# 18                                    Biophysical journal  2016.0   Feb
# 19                                    Biophysical journal  2016.0   Feb
# 20                                    Biophysical journal  2016.0   Feb
# 21                                    Biophysical journal  2016.0   Feb
# 22                                    Biophysical journal  2016.0   Feb
# 23                                          PLoS genetics  2016.0   Mar
# 24                                          PLoS genetics  2016.0   Mar
# 25                                          PLoS genetics  2016.0   Mar
# 26                                  Biotechnology letters  2016.0   Jul
# 27                                  Biotechnology letters  2016.0   Jul
# 28                                     Scientific reports  2016.0   Mar
# 29                                     Scientific reports  2016.0   Mar
# ...                                                   ...     ...   ...
# 357012                    Chemico-biological interactions  2011.0   May
# 357013                                        Chemosphere  2011.0   Feb
# 357014                                             Stroke  2011.0   Feb
# 357015  Biochemical and biophysical research communica...  2011.0   Jan
# 357016  Biochemical and biophysical research communica...  2011.0   Jan
# 357017  Biochemical and biophysical research communica...  2011.0   Jan
# 357018  Biochemical and biophysical research communica...  2011.0   Jan
# 357019  Biochemical and biophysical research communica...  2011.0   Jan
# 357020  Biochemical and biophysical research communica...  2011.0   Jan
# 357021                                BMC systems biology  2010.0   Dec
# 357022  Biochemical and biophysical research communica...  2011.0   Feb
# 357023  Biochemical and biophysical research communica...  2011.0   Feb
# 357024  Biochemical and biophysical research communica...  2011.0   Feb
# 357025  Biochemical and biophysical research communica...  2011.0   Feb
# 357026                          Molecular biology reports  2011.0   Nov
# 357027                          Molecular biology reports  2011.0   Nov
# 357028                    International journal of cancer  2011.0   Nov
# 357029                           Synapse (New York, N.Y.)  2011.0   Aug
# 357030  Thyroid : official journal of the American Thy...  2011.0   Apr
# 357031               The Journal of comparative neurology  2011.0   Feb
# 357032                                    Atherosclerosis  2011.0   Mar
# 357033  Journal of applied physiology (Bethesda, Md. :...  2011.0   Apr
# 357034                               Neuroscience letters  2011.0   Mar
# 357035  European journal of cancer (Oxford, England : ...  2011.0   May
# 357036                                     Brain research  2011.0   Mar
# 357037                                     Brain research  2011.0   Mar
# 357038                                            Vaccine  2011.0   Feb
# 357039                   Dermatology (Basel, Switzerland)  2011.0   Feb
# 357040                   Dermatology (Basel, Switzerland)  2011.0   Feb
# 357041                                   Molecular vision  2010.0   Dec
#
#        impact_factor                                           abstract  \
# 0              3.042  The human neutrophil antigen-3 (HNA-3) epitope...
# 1              3.042  The human neutrophil antigen-3 (HNA-3) epitope...
# 2              4.517  APOBEC-3 proteins induce C-to-U hypermutations...
# 3              5.138  Congenital adrenal hyperplasia (CAH) due to 21...
# 4              3.042  CD59 is a cell surface glycoprotein of approxi...
# 5              3.094  Caspase-8 deficiency (CED) was originally desc...
# 6             12.384  Complement-mediated vasculopathy of muscle and...
# 7             12.384  Complement-mediated vasculopathy of muscle and...
# 8             12.384  Complement-mediated vasculopathy of muscle and...
# 9             12.384  Complement-mediated vasculopathy of muscle and...
# 10             7.870  Brain-derived neurotrophic factor (BDNF) plays...
# 11             7.870  Metastases are the major cause of melanoma-rel...
# 12               0.5  Type 1 diabetes mellitus (T1D) is characterize...
# 13             3.445  Increased fragility has been described in huma...
# 14             1.347  Depression is a worldwide public health issue,...
# 15             4.179  It was hypothesized that IL-1 antagonism would...
# 16               0.5  While Syk has been shown to associate with TLR...
# 17             3.427  Toll-like receptor 4 (TLR4) activation in panc...
# 18             3.632  The process of protein complex dissociation re...
# 19             3.632  The process of protein complex dissociation re...
# 20             3.632  The process of protein complex dissociation re...
# 21             3.632  The process of protein complex dissociation re...
# 22             3.632  The molecular basis for excitation-contraction...
# 23             6.661  Human APOBEC3 cytidine deaminases are intrinsi...
# 24             6.661  Human APOBEC3 cytidine deaminases are intrinsi...
# 25             6.661  Human APOBEC3 cytidine deaminases are intrinsi...
# 26             1.639  To search for a novel glutamate decarboxylase ...
# 27             1.639  To search for a novel glutamate decarboxylase ...
# 28             5.228  Fatty acid oxidation and subsequent ketogenesi...
# 29             5.228  Asymmetric and symmetric dimethylarginines (AD...
# ...              ...                                                ...
# 357012         2.618  Prolonged exposure to estrogens is a significa...
# 357013         3.698  Reduction in DNA repair capacity is associated...
# 357014         5.787  Familial hemiplegic migraine is characterized ...
# 357015         2.371  The polycystic kidney disease 1-like 3 (PKD1L3...
# 357016         2.371  The polycystic kidney disease 1-like 3 (PKD1L3...
# 357017         2.371  The polycystic kidney disease 1-like 3 (PKD1L3...
# 357018         2.371  The polycystic kidney disease 1-like 3 (PKD1L3...
# 357019         2.371  The polycystic kidney disease 1-like 3 (PKD1L3...
# 357020         2.371  The polycystic kidney disease 1-like 3 (PKD1L3...
# 357021         2.213  Obesity causes insulin resistance in target ti...
# 357022         2.371  Sarcoplasmic reticulum Ca(2+) ATPase (SERCA) i...
# 357023         2.371  Sarcoplasmic reticulum Ca(2+) ATPase (SERCA) i...
# 357024         2.371  Sarcoplasmic reticulum Ca(2+) ATPase (SERCA) i...
# 357025         2.371  Sarcoplasmic reticulum Ca(2+) ATPase (SERCA) i...
# 357026         1.698  DNA repair genetic polymorphisms have been stu...
# 357027         1.698  DNA repair genetic polymorphisms have been stu...
# 357028         5.531  Pilocytic astrocytoma (PA) is emerging as a tu...
# 357029           0.5  Animal models provide compelling evidence that...
# 357030         3.784  Although hereditary nonmedullary thyroid cance...
# 357031           0.5  Previous studies in the developing mouse thala...
# 357032         3.942  Ischemic stroke is prevalent in type 2 diabete...
# 357033           0.5  Patients with chronic heart failure (HF) frequ...
# 357034         2.107  An outbred rat model of the novelty-seeking ph...
# 357035           0.5  Biallelic mutations in the base excision repai...
# 357036         2.561  The catechol-O-methyl-transferase (COMT) gene ...
# 357037         2.561  The catechol-O-methyl-transferase (COMT) gene ...
# 357038         3.413  Since long-term immunity is a critical compone...
# 357039           0.5  Epidermodysplasia verruciformis Lewandowsky-Lu...
# 357040           0.5  Epidermodysplasia verruciformis Lewandowsky-Lu...
# 357041         2.110  To investigate whether single nucleotide polym...
#
#                  variant_id                                     protein_domain
# 0                       NaN                                                NaN
# 1                       NaN                                                NaN
# 2                       NaN                                                NaN
# 3                       NaN                                                NaN
# 4       chr11:g.33738939del                                                NaN
# 5                       NaN                                                NaN
# 6                       NaN                                                NaN
# 7                       NaN                                                NaN
# 8                       NaN                                                NaN
# 9                       NaN                                                NaN
# 10                      NaN                                                NaN
# 11      chr7:g.140453136A>T  Protein kinase domain|Protein kinase-like doma...
# 12                      NaN                                                NaN
# 13        chr9:g.5073770G>T  Protein kinase domain|Protein kinase-like doma...
# 14                      NaN                                                NaN
# 15                      NaN                                                NaN
# 16                      NaN                                                NaN
# 17                      NaN                                                NaN
# 18                      NaN                                                NaN
# 19                      NaN                                                NaN
# 20                      NaN                                                NaN
# 21                      NaN                                                NaN
# 22                      NaN                                                NaN
# 23                      NaN                                                NaN
# 24                      NaN                                                NaN
# 25                      NaN                                                NaN
# 26                      NaN                                                NaN
# 27                      NaN                                                NaN
# 28                      NaN                                                NaN
# 29       chr5:g.34998877C>G  Pyridoxal phosphate-dependent transferase|Pyri...
# ...                     ...                                                ...
# 357012                  NaN                                                NaN
# 357013                  NaN                                                NaN
# 357014                  NaN                                                NaN
# 357015                  NaN                                                NaN
# 357016                  NaN                                                NaN
# 357017                  NaN                                                NaN
# 357018                  NaN                                                NaN
# 357019                  NaN                                                NaN
# 357020                  NaN                                                NaN
# 357021                  NaN                                                NaN
# 357022                  NaN                                                NaN
# 357023                  NaN                                                NaN
# 357024                  NaN                                                NaN
# 357025                  NaN                                                NaN
# 357026                  NaN                                                NaN
# 357027                  NaN                                                NaN
# 357028                  NaN                                                NaN
# 357029                  NaN                                                NaN
# 357030                  NaN                                                NaN
# 357031                  NaN                                                NaN
# 357032                  NaN                                                NaN
# 357033                  NaN                                                NaN
# 357034                  NaN                                                NaN
# 357035                  NaN                                                NaN
# 357036                  NaN                                                NaN
# 357037                  NaN                                                NaN
# 357038                  NaN                                                NaN
# 357039                  NaN                                                NaN
# 357040                  NaN                                                NaN
# 357041                  NaN                                                NaN
#
# [357042 rows x 11 columns]

# %%
df1 = df.iloc[0:10,:]

# %%
df1
# Out:
#        gene protein_variant      pmid  \
# 0         T     p.Leu153Phe  22040064
# 1   SLC44A2     p.Arg154Gln  22040064
# 2  APOBEC-1     p.Glu181Gln  22326345
# 3   CYP21A2     p.Val281Leu  22886582
# 4      CD59       c.146delA  24383981
# 5         T       c.1096C>T  25814141
# 6       C4A       p.Cys4Ala  26493816
# 7       C4B       p.Cys4Asx  26493816
# 8       C4A       p.Cys4Asx  26493816
# 9       C4B       p.Cys4Ala  26493816
#
#                                                title  \
# 0  Frequencies of SLC44A2 alleles encoding human ...
# 1  Frequencies of SLC44A2 alleles encoding human ...
# 2  Hypermutation of ApoB mRNA by rat APOBEC-1 ove...
# 3  Complement component 4 copy number variation a...
# 4  A new blood group antigen is defined by anti-C...
# 5  Caspase-8 Deficiency Presenting as Late-Onset ...
# 6  Gene copy-number variations (CNVs) of compleme...
# 7  Gene copy-number variations (CNVs) of compleme...
# 8  Gene copy-number variations (CNVs) of compleme...
# 9  Gene copy-number variations (CNVs) of compleme...
#
#                             journal    year month impact_factor  \
# 0                       Transfusion  2012.0   May         3.042
# 1                       Transfusion  2012.0   May         3.042
# 2      Journal of molecular biology  2012.0   Apr         4.517
# 3                    Human genetics  2012.0   Dec         5.138
# 4                       Transfusion  2014.0   Jul         3.042
# 5    Journal of clinical immunology  2015.0   May         3.094
# 6  Annals of the rheumatic diseases  2016.0   Sep        12.384
# 7  Annals of the rheumatic diseases  2016.0   Sep        12.384
# 8  Annals of the rheumatic diseases  2016.0   Sep        12.384
# 9  Annals of the rheumatic diseases  2016.0   Sep        12.384
#
#                                             abstract           variant_id  \
# 0  The human neutrophil antigen-3 (HNA-3) epitope...                  NaN
# 1  The human neutrophil antigen-3 (HNA-3) epitope...                  NaN
# 2  APOBEC-3 proteins induce C-to-U hypermutations...                  NaN
# 3  Congenital adrenal hyperplasia (CAH) due to 21...                  NaN
# 4  CD59 is a cell surface glycoprotein of approxi...  chr11:g.33738939del
# 5  Caspase-8 deficiency (CED) was originally desc...                  NaN
# 6  Complement-mediated vasculopathy of muscle and...                  NaN
# 7  Complement-mediated vasculopathy of muscle and...                  NaN
# 8  Complement-mediated vasculopathy of muscle and...                  NaN
# 9  Complement-mediated vasculopathy of muscle and...                  NaN
#
#   protein_domain
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN

# %%
len(df)
# Out:
# 357042

# %%
dj1 = df1.to_json(orient='records')

# %%
output = '['
for i in range(len(df1)):
    row = df1.iloc[i:i+1,:].to_json(orient='records')[1:-1]
    output = output + '{"model":"deepb.pubmed","pk":%i,"fields":%s},'%(i,row)
output = output[:-1]+']'

# %%
output
# Out:
# '[{"model":"deepb.pubmed","pk":0,"fields":{"gene":"T","protein_variant":"p.Leu153Phe","pmid":22040064,"title":"Frequencies of SLC44A2 alleles encoding human neutrophil antigen-3 variants in the African American population.","journal":"Transfusion","year":2012.0,"month":"May","impact_factor":"3.042","abstract":"The human neutrophil antigen-3 (HNA-3) epitopes reside on the choline transporter-like protein-2 (CTL2). A single-nucleotide substitution (461G>A; Arg154Gln) on the CTL2 gene (SLC44A2) defines the allele SLC44A2*1, which expresses HNA-3a, and SLC44A2*2, which expresses HNA-3b; an additional substitution (457C>T; Leu153Phe) in SLC44A2*1:2 may impact genotyping systems. People who only express HNA-3b may develop anti-HNA-3a. These alloantibodies have been linked to severe transfusion-related acute lung injury, which may be a reason to screen blood donors for SLC44A2*2 homozygosity. For Caucasian and Asian populations, SLC44A2 allele frequencies are known. Our primary objective was to determine the SLC44A2 allele frequencies in the African American population. Purified DNA from 334 individuals (202 male, 132 female; 241 African American, 93 Caucasian) was collected. Two real-time polymerase chain reaction assays were developed to genotype all samples; results were confirmed by nucleotide sequencing. In 241 African American donors, the allele frequency of SLC44A2*1 was 93% (85%-<100%; 95% confidence intervals, Poisson distribution) while SLC44A2*2 was 7% (5%-10%). In 93 Caucasian donors, the allele frequency of SLC44A2*1 was 83% (71%-98%) and SLC44A2*2 was 17% (11%-24%), matching previously reported data for Caucasians but differing from African Americans (p\\u2003<\\u20030.001, Fisher\'s exact test). This study describes the allele frequencies of the three known HNA-3 variants in an African American population. We found that African Americans have a significantly lower probability of possessing the SLC44A2*2 allele and may thus be less likely to form the clinically relevant anti-HNA-3a.","variant_id":null,"protein_domain":null}},{"model":"deepb.pubmed","pk":1,"fields":{"gene":"SLC44A2","protein_variant":"p.Arg154Gln","pmid":22040064,"title":"Frequencies of SLC44A2 alleles encoding human neutrophil antigen-3 variants in the African American population.","journal":"Transfusion","year":2012.0,"month":"May","impact_factor":"3.042","abstract":"The human neutrophil antigen-3 (HNA-3) epitopes reside on the choline transporter-like protein-2 (CTL2). A single-nucleotide substitution (461G>A; Arg154Gln) on the CTL2 gene (SLC44A2) defines the allele SLC44A2*1, which expresses HNA-3a, and SLC44A2*2, which expresses HNA-3b; an additional substitution (457C>T; Leu153Phe) in SLC44A2*1:2 may impact genotyping systems. People who only express HNA-3b may develop anti-HNA-3a. These alloantibodies have been linked to severe transfusion-related acute lung injury, which may be a reason to screen blood donors for SLC44A2*2 homozygosity. For Caucasian and Asian populations, SLC44A2 allele frequencies are known. Our primary objective was to determine the SLC44A2 allele frequencies in the African American population. Purified DNA from 334 individuals (202 male, 132 female; 241 African American, 93 Caucasian) was collected. Two real-time polymerase chain reaction assays were developed to genotype all samples; results were confirmed by nucleotide sequencing. In 241 African American donors, the allele frequency of SLC44A2*1 was 93% (85%-<100%; 95% confidence intervals, Poisson distribution) while SLC44A2*2 was 7% (5%-10%). In 93 Caucasian donors, the allele frequency of SLC44A2*1 was 83% (71%-98%) and SLC44A2*2 was 17% (11%-24%), matching previously reported data for Caucasians but differing from African Americans (p\\u2003<\\u20030.001, Fisher\'s exact test). This study describes the allele frequencies of the three known HNA-3 variants in an African American population. We found that African Americans have a significantly lower probability of possessi ...

# %%
[
  {
    "model": "myapp.person",
    "pk": 1,
    "fields": {
      "first_name": "John",
      "last_name": "Lennon"
    }
  },
  {
    "model": "myapp.person",
    "pk": 2,
    "fields": {
      "first_name": "Paul",
      "last_name": "McCartney"
    }
  }
]

# %%
output = '['
for i in range(len(df)):
    row = df.iloc[i:i+1,:].to_json(orient='records')[1:-1]
    output = output + '{"model":"deepb.pubmed","pk":%i,"fields":%s},'%(i,row)
output = output[:-1]+']'

# %%
with open('pubmed_data.json', 'w') as f:
    f.write(output)

# %%
import time

# %%
time.time()
# Out:
# 1493161608.010493

# %%
ls
# Out:
# ACMG.py*                   amino_acid_mapping.py*     dataloader.py*             main.pyc                   pubmed.pyc                 tests.py
# ACMG.pyc                   amino_acid_mapping.pyc     dataloader.pyc             map_phenotype_to_gene.py*  result/                    urls.py
# README.md                  apps.py                    eval.py*                   map_phenotype_to_gene.pyc  static/                    urls.pyc
# __init__.py                apps.pyc                   fixtures/                  migrations/                tasks.py                   views.py
# __init__.pyc               collectVariantInfo.py*     getInterproDomain.py*      models.py                  tasks.pyc                  views.pyc
# admin.py                   collectVariantInfo.pyc     input/                     models.pyc                 templates/
# admin.pyc                  data/                      main.py                    pubmed.py*                 test.ipynb

# %%
with open('input/', 'r') as myfile:
    data=myfile.read().replace('\n', '')

# %%
raw_input = Raw_input_table.objects.get(id=raw_input_id)
input_gene = raw_input.raw_input_gene
input_phenotype = raw_input.raw_input_phenotype

# input_gene_list = [i.split('\t') for i in input_gene.split('\n')]
# df_genes = pd.DataFrame(input_gene_list[1:-1], columns=input_gene_list[0])
df_genes = pd.read_csv(StringIO(input_gene), sep = '\t')
CANDIDATE_GENES = pd.unique(df_genes.Gene.values).tolist()

corner_cases = dict()
phenos = []
input_phenotype = input_phenotype.split('\n')
for line in input_phenotype:
    if line.startswith('#') or not line.strip():
        continue
    line = line.rstrip()
    phenos += line.split(',')
    for pheno in phenos:
        if re.search('development', pheno) and re.search('delay', pheno) and not re.search('growth', pheno):
            phenos.append('growth delay')
            corner_cases['growth delay'] = pheno.strip()
    for pheno in phenos:
        if re.search('growth', pheno) and re.search('delay', pheno) and not re.search('development', pheno):
            phenos.append('developmental delay')
            corner_cases['developmental delay'] = pheno.strip()
phenos = [_.strip() for _ in phenos]

# %%
ls
# Out:
# ACMG.py*                   amino_acid_mapping.py*     dataloader.py*             main.pyc                   pubmed.pyc                 tests.py
# ACMG.pyc                   amino_acid_mapping.pyc     dataloader.pyc             map_phenotype_to_gene.py*  result/                    urls.py
# README.md                  apps.py                    eval.py*                   map_phenotype_to_gene.pyc  static/                    urls.pyc
# __init__.py                apps.pyc                   fixtures/                  migrations/                tasks.py                   views.py
# __init__.pyc               collectVariantInfo.py*     getInterproDomain.py*      models.py                  tasks.pyc                  views.pyc
# admin.py                   collectVariantInfo.pyc     input/                     models.pyc                 templates/
# admin.pyc                  data/                      main.py                    pubmed.py*                 test.ipynb

# %%
import pandas as pd

# %%
dfg = pd.read_csv('input/input_genes.txt', sep = '\t')

# %%
input_gene = dfg.to_json(orient='records')

# %%
import map_phenotype_to_gene
import collectVariantInfo
import pubmed
import ACMG
import filterVariantOnPhenotype
import csv

import pandas as pd
import numpy as np
import re
import myvariant
from deepb.models import Main_table, Raw_input_table
from io import StringIO
from collections import Counter

# input_phenotype = 'data/sample_patient_phenotype.txt'
# input_genes = 'data/sample_genes.txt'

def format_hgvs(chrom, pos, ref, alt):
    '''get a valid hgvs name from VCF-style "chrom, pos, ref, alt" data.

    Example:

        >>> myvariant.format_hgvs("1", 35366, "C", "T")
        >>> myvariant.format_hgvs("2", 17142, "G", "GA")
        >>> myvariant.format_hgvs("MT", 8270, "CACCCCCTCT", "C")
        >>> myvariant.format_hgvs("X", 107930849, "GGA", "C")

    '''
    chrom = str(chrom)
    if chrom.lower().startswith('chr'):
        # trim off leading "chr" if any
        chrom = chrom[3:]
    if len(ref) == len(alt) == 1:
        # this is a SNP
        hgvs = 'chr{0}:g.{1}{2}>{3}'.format(chrom, pos, ref, alt)
    elif len(ref) > 1 and len(alt) == 1:
        # this is a deletion:
        if ref[0] == alt:
            start = int(pos) + 1
            end = int(pos) + len(ref) - 1
            hgvs = 'chr{0}:g.{1}_{2}del'.format(chrom, start, end)
        else:
            end = int(pos) + len(ref) - 1
            hgvs = 'chr{0}:g.{1}_{2}delins{3}'.format(chrom, pos, end, alt)
    elif len(ref) == 1 and len(alt) > 1:
        # this is a insertion
        if alt[0] == ref:
            hgvs = 'chr{0}:g.{1}_{2}ins'.format(chrom, pos, int(pos) + 1)
            ins_seq = alt[1:]
            hgvs += ins_seq
        else:
            hgvs = 'chr{0}:g.{1}delins{2}'.format(chrom, pos, alt)
    elif len(ref) > 1 and len(alt) > 1:
        end = int(pos) + len(alt) - 1
        hgvs = 'chr{0}:g.{1}_{2}delins{3}'.format(chrom, pos, end, alt)
    else:
        raise ValueError("Cannot convert {} into HGVS id.".format((chrom, pos, ref, alt)))
    return hgvs

def read_input_pheno_file(input_phenotype):
        if not input_phenotype:
            return '', ''
        text = StringIO(unicode(input_phenotype), newline=None)
        lines = text.readlines()
        lines = [line.strip() for line in lines]
        phenos = []
        for line in lines:
            if not line:
                continue
            phenos_each_line = re.split(r'  +|\t+|,|;|\.|\|', line.strip())
            phenos_each_line = [re.sub(r'^\W+|\W+$', '', s) for s in phenos_each_line]
            phenos_each_line = [s for s in phenos_each_line if s]
            phenos += phenos_each_line

        corner_cases = dict()
        for pheno in phenos:
                if re.search('development', pheno) and re.search('delay', pheno) and not re.search('growth', pheno):
                        phenos.append('growth delay')
                        corner_cases['growth delay'] = pheno.strip()
        for pheno in phenos:
                if re.search('growth', pheno) and re.search('delay', pheno) and not re.search('development', pheno):
                        phenos.append('developmental delay')
                        corner_cases['developmental delay'] = pheno.strip()
        return phenos, corner_cases

def read_input_gene_file(input_gene):
        candidate_vars = []
        input_gene = input_gene.split('\n')
        header = input_gene[0]
        sniffer = csv.Sniffer()
        dialect = sniffer.sniff(header)
        delimiter =  dialect.delimiter
        field_names = header.split(delimiter)
        chrom_idx, pos_idx, ref_idx, alt_idx, gene_idx = None, None, None, None, 0 

        for idx in xrange(len(field_names)):
            field = field_names[idx]
            if re.match(r'chrom', field, re.I): chrom_idx = idx
            if re.match(r'pos|start', field, re.I): pos_idx = idx
            if re.match(r'ref', field, re.I): ref_idx = idx
            if re.match(r'alt|allele 1', field, re.I): alt_idx = idx
            if re.match(r'gene (gene)|gene', field, re.I): gene_idx = idx

        input_gene_list = []
        CANDIDATE_GENES = []
        for line in input_gene[1:]:
                if not line:
                        continue
                line = line.rstrip()
                parts = re.split(r'%s' % delimiter, line)
                input_gene_list.append(parts)
                gene = parts[gene_idx]
                CANDIDATE_GENES.append(gene)
                transcript, variant, variant_id = '', '', ''
                for part in parts:
                    if re.search(r'_.*:c\.', part):
                        transcript, variant = part.split(':')
                    if re.search(r'_.*:g\.', part):
                        variant_id = 'chr' + part.split(':')[0].split('.')[-1] + part.split(':')[-1]
                    if re.search(r'chr.*:g\.', part, re.I):
                        variant_id = part
                if not variant_id and (chrom_idx and pos_idx and ref_idx and alt_idx):
                    chrome, pos, ref, alt = parts[chrom_idx], parts[pos_idx], parts[ref_idx], parts[alt_idx]
                    variant_id = format_hgvs(chrome, pos, ref, alt)
                candidate_vars.append((gene, variant, transcript, variant_id))

        # remove lines in the input file which has wrong number of fields
        field_nums = []
        for line in input_gene_list:
            field_nums.append(len(line))
        count = Counter(field_nums)
        correct_field_num = count.most_common()[0][0]
        correct_input_gene_list = []
        for line in input_gene_list:
                if len(line) == correct_field_num:
                        correct_input_gene_list.append(line)
        df_genes = pd.DataFrame(correct_input_gene_list, columns = field_names)
        return candidate_vars, CANDIDATE_GENES, df_genes, field_names 

def map_phenotype2gene(CANDIDATE_GENES, phenos, corner_cases, candidate_vars):
        ranking_genes, ranking_disease = map_phenotype_to_gene.generate_score(phenos, CANDIDATE_GENES, corner_cases)
        # collect variant info
        hpo_filtered_genes = np.unique([i[0] for i in ranking_genes]).tolist()

        tmp_candidate_vars = []
        for var in candidate_vars:
                if var[0] in hpo_filtered_genes:
                        tmp_candidate_vars.append(var)
        candidate_vars = tmp_candidate_vars
        return ranking_genes, candidate_vars

raw_input = Raw_input_table.objects.get(id=raw_input_id)
input_gene = open("/Users/Tianqi/Desktop/xiaonantest1_g.txt",'rU').read()
input_phenotype = open("/Users/Tianqi/Desktop/xiaonantest1_p.txt",'rU').read()

# Read input pheno file and generate phenos and corner_cases 
phenos, corner_cases = read_input_pheno_file(input_phenotype)

# Read input gene file and generate candidate_vars. candidate_vars are (gene, variant, transcript, variant_id); CANDIDATE_GENES is a list of gene symbols; df_genes is a dataframe that keeps all the data that user uploaded; field_names are header of the input gene file 
candidate_vars, CANDIDATE_GENES, df_genes, field_names = read_input_gene_file(input_gene)

# map phenotype to gene; the candidate_vars was filtered: if it is a gene associated with phenos, then keep it.
if phenos:
    ranking_genes, candidate_vars = map_phenotype2gene(CANDIDATE_GENES, phenos, corner_cases, candidate_vars)
else:
    ranking_genes = []
    for gene in CANDIDATE_GENES:
        ranking_genes.append((gene, 1.0, 1))

# collect variant info
mv = myvariant.MyVariantInfo()
final_res, variants = collectVariantInfo.get_variants(candidate_vars)

# pubmed
df_pubmed = pubmed.queryPubmedDB(final_res)

# ACMG
df_hpo_ranking_genes = pd.DataFrame(ranking_genes, columns=['gene', 'score', 'hits'])
df_hpo_ranking_genes = df_hpo_ranking_genes[['gene', 'score']]
ACMG_result = ACMG.Get_ACMG_result(df_hpo_ranking_genes, variants, df_pubmed)

# filter variant on phenotype
if phenos:
    df_final_res = filterVariantOnPhenotype.generateOutput(variants, ACMG_result, phenos)
else:
    df_final_res = ACMG_result

return df_final_res, df_genes, phenos, field_names
